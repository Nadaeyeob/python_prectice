# %% [markdown]
# ### Confusion Matrix

# %%
from IPython.display import Image 
Image('C:/Users/sw993/OneDrive/바탕 화면/ML/Confusion Matrix.png')

# %% [markdown]
# #### Accuracy = (TP + TN) / (TP+TN+FP+FN) -> Positive, Negative 예측 정확도
# #### Precision = (TP) / (TP + FP) -> Positive로 예측했을 때 실제 맞을 경우
# #### Recall = (TP) / (TP + FN) -> 실제 Positive일 때 맞게 예측했을 때

# %%
from sklearn.metrics import accuracy_score, precision_score,recall_score,confusion_matrix
from sklearn.metrics import precision_recall_curve,f1_score,roc_curve,roc_auc_score
